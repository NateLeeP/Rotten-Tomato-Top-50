# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import re
import os

# %%
os.chdir(r'C:\Users\Nate P\Desktop\Rotten Tomatoes Movies Analysis')
rotten_tomatoes_template_url = 'https://www.rottentomatoes.com/m/{}'

# %%
url = 'https://www.rottentomatoes.com/m/avengers_endgame/'
html_text = requests.get(url).text
soup = bs(html_text)

# %%
# The information we want - Ratings, Director, and Studio - can be found in the <li> tags with class type 'meta-row clearfix'
soup.findAll('li', 'meta-row clearfix')
# Out:
# [<li class="meta-row clearfix">
#  <div class="meta-label subtle">Rating: </div>
#  <div class="meta-value">PG-13 (for sequences of sci-fi violence and action, and some language)</div>
#  </li>, <li class="meta-row clearfix">
#  <div class="meta-label subtle">Genre: </div>
#  <div class="meta-value">
#  <a href="/browse/opening/?genres=1">Action &amp; Adventure</a>,
#
#                                  <a href="/browse/opening/?genres=9">Drama</a>,
#
#                                  <a href="/browse/opening/?genres=14">Science Fiction &amp; Fantasy</a>
#  </div>
#  </li>, <li class="meta-row clearfix">
#  <div class="meta-label subtle">Directed By: </div>
#  <div class="meta-value">
#  <a href="/celebrity/joe_russo">Joe Russo</a>,
#
#                                  <a href="/celebrity/anthony_russo">Anthony Russo</a>
#  </div>
#  </li>, <li class="meta-row clearfix">
#  <div class="meta-label subtle">Written By: </div>
#  <div class="meta-value">
#  <a href="/celebrity/christopher_markus">Christopher Markus</a>,
#
#                                  <a href="/celebrity/stephen_mcfeely">Stephen McFeely</a>
#  </div>
#  </li>, <li class="meta-row clearfix">
#  <div class="meta-label subtle">In Theaters: </div>
#  <div class="meta-value">
#  <time datetime="2019-04-25T17:00:00-07:00">Apr 26, 2019</time>
#  <span style="text-transform:capitalize"> wide</span>
#  </div>
#  </li>, <li class="meta-row clearfix">
#  <div class="meta-label subtle">On Disc/Streaming: </div>
#  <div class="meta-value">
#  <time datetime="2019-07-29T17:00:00-07:00">Jul 30, 2019</time>
#  </div>
#  </li>, <li class="meta-row clearfix">
#  <div class="meta-label subtle">Runtime: </div>
#  <div class="meta-value">
#  <time datetime="P182M">
#                                  182 minutes
#                              </time>
#  </div>
#  </li>, <li class="meta-row clearfix">
#  <div class="meta-label subtle">Studio: </div>
#  <div class="meta-value">
#                          Marvel Studios
#                      </div>
#  </li>]

# %%
# Below is previous idea for extracting Rating, Directors, and Studio. Goal was to find each category AFTER ':' using
# backwards looking. Issue in the 'Rating' category, as 'G' rated films did NOT have '('. This issue was hard to notice originally,
# as the search would return a 'None' object when a '(' was not found. 
for tag in soup.findAll('li','meta-row clearfix'):
    text = ' '.join(tag.text.split())
    if 'Rating' in text:
        print(re.search(r'(?<=: ).+\(', text)[0].strip('(').strip())
    if 'Directed By' in text:
        print(re.search(r'(?<=: ).+', text)[0])
    if 'Studio' in text:
        print(re.search(r'(?<=: ).+', text)[0])
# Out:
# PG-13
# Joe Russo, Anthony Russo
# Marvel Studios

# %%
# Read in movies df, extract title and year
movies_df = pd.read_csv('movies_df.csv')
movies_df.head()
# Out:
#                                         Title  Box Office in $  Release Year  \
# 0                           Avengers: Endgame       2798000000          2019
# 1                                      Avatar       2790000000          2009
# 2                                     Titanic       2188000000          1997
# 3  Star Wars: Episode VII - The Force Awakens       2068000000          2015
# 4                      Avengers: Infinity War       2048000000          2018
#
#    Rotten Score
# 0            94
# 1            82
# 2            89
# 3            93
# 4            85

# %%
# List of Studio, Director, and Rating. List will be populated using a function 'scrape_movie_page'
studios = []
directors = []
ratings = []

# %%
# Function for extracting studio, director, and rating
def scrape_movie_page(response):
    # Function is passed a response object. A soup object is created during each function call
    soup = bs(response.text)
    for tag in soup.findAll('li','meta-row clearfix'):
        # Eliminate unnecessary blanks
        text = ' '.join(tag.text.split())
        if 'Rating' in text:
            # Two different regex patterns. One for ratings that have a '(', one for those without (G ratings)
            if '(' in text:
                #print((re.search(r'(?<=: ).+\(', text)[0].strip('(').strip()))
                # Print out of each result was to check what movie caused problems during the iteration of the urls. 
                ratings.append((re.search(r'(?<=: ).+\(', text)[0].strip('(').strip()))
            else:
                #print((re.search(r'(?<=: ).+', text)[0].strip()))
                ratings.append((re.search(r'(?<=: ).+', text)[0].strip()))
        if 'Directed By' in text:
            #print(re.search(r'(?<=: ).+', text)[0])
            directors.append(re.search(r'(?<=: ).+', text)[0])
        if 'Studio' in text:
            #print(re.search(r'(?<=: ).+', text)[0])
            studios.append(re.search(r'(?<=: ).+', text)[0])

# %%
# Movie names and release years. Will be used to build urls. 
movie_titles = list(movies_df['Title'])
movie_release_years = list(movies_df['Release Year'])

# %%
# Practice with format. Notice, ahve to replace "'" with a blank before combining. 
url = rotten_tomatoes_template_url.format('_'.join(re.sub(r'[:\-]',' ','Toy Story 4').replace('\'','').lower().split()))
url
# Out:
# 'https://www.rottentomatoes.com/m/toy_story_4'

# %%
# looping over movie titles, creating url
# Had to get creative with URL creation. Could not replace apostrophe ("'s") with blank space, creating an error with 'Avenger's' (avengers_s).
# Could not replace every non letter character with '', as this messed up 'Spider-man, Far from home' (creating spiderman, not spider_man)
# Decided to make non-word a space, while making "'" an empty space ('')
# .split() method then splits the sentence on the blank spaces (" "), then join combines them. 
root_url = 'https://www.rottentomatoes.com/m/{}'
for i, title in enumerate(movie_titles):
    # For loop goes through each movie title, then creates url out of title. 
    url = root_url.format('_'.join(re.sub(r'[:\-]',' ',title).replace('\'','').lower().split()))
    year = '_' + str(movie_release_years[i])
    #print(title)
    # If/else statement checks to see if a request is valid, specifically checking to see 'url+year' is valid
    # Reason is some movies repeat, i.e. lion king is on list twice. Would be great if every movie could be found using 'url' + 'year',
    # but unfortunately not the case. First try request that uses name + year, and if not found, moves on to just name. 
    if requests.get(url + year):
        scrape_movie_page(requests.get(url+year))
    else:
        scrape_movie_page(requests.get(url))

# %%
# Check to see if all categories were scraped. 
print(len(studios))
print(len(directors))
print(len(ratings))
# Out:
# 50
# 50
# 50

# %%
#Success!! Save studios, directors, and ratings as DF so no need to scrape 
studios_df = pd.DataFrame([movie_titles, ratings, studios, directors]).T
studios_df.columns = ['Title', 'Ratings','Studio','Director(s)']

# %%
studios_df.to_csv('studios_df_v2.csv', index = False)

# %%
studios_df
# Out:
#                                             Title Ratings  \
# 0                               Avengers: Endgame   PG-13
# 1                                          Avatar   PG-13
# 2                                         Titanic   PG-13
# 3      Star Wars: Episode VII - The Force Awakens   PG-13
# 4                          Avengers: Infinity War   PG-13
# 5                                  Jurassic World   PG-13
# 6                                   The Lion King      PG
# 7                           Marvel's The Avengers   PG-13
# 8                                       Furious 7   PG-13
# 9                         Avengers: Age of Ultron   PG-13
# 10                                      Frozen II      PG
# 11                                  Black Panther   PG-13
# 12  Harry Potter and the Deathly Hallows - Part 2   PG-13
# 13                       Star Wars: The Last Jedi   PG-13
# 14                 Jurassic World: Fallen Kingdom   PG-13
# 15                                         Frozen      PG
# 16                           Beauty and the Beast      PG
# 17                                  Incredibles 2      PG
# 18                        The Fate of the Furious   PG-13
# 19                                     Iron Man 3   PG-13
# 20                                        Minions      PG
# 21                     Captain America: Civil War   PG-13
# 22                                        Aquaman   PG-13
# 23                      Spider-Man: Far From Home   PG-13
# 24                                 Captain Marvel   PG-13
# 25                 Transformers: Dark of the Moon   PG-13
# 26  The Lord of the Rings: The Return of the King   PG-13
# 27                                        Skyfall   PG-13
# 28                Transformers: Age of Extinction   PG-13
# 29                          The Dark Knight Rises   PG-13
# 30                                    Toy Story 4       G
# 31                                    Toy Story 3       G
# 32     Pirates of the Caribbean: Dead Man's Chest   PG-13
# 33                                          Joker       R
# 34                   Rogue One: A Star Wars Story   PG-13
# 35                                        Aladdin      PG
# 36    Pirates of the Caribbean: On Stranger Tides   PG-13
# 37                                Despicable Me 3      PG
# 38                                  Jurassic Park   PG-13
# 39                                   Finding Dory      PG
# 40      Star Wars: Episode I - The Phantom Menace      PG
# 41                            Alice in Wonderland      PG
# 42                                       Zootopia      PG
# 43              The Hobbit: An Unexpected Journey   PG-13
# 44                                The Dark Knight   PG-13
# 45               Star Wars: The Rise of Skywalker   PG-13
# 46          Harry Potter and the Sorcerer's Stone      PG
# 47                                Despicable Me 2      PG
# 48                                  The Lion King       G
# 49                                The Jungle Book      PG
#
#                              Studio                              Director(s)
# 0                    Marvel Studios                 Joe Russo, Anthony Russo
# 1                  20th Century Fox                            James Cameron
# 2                Paramount Pictures                            James Cameron
# 3              Walt Disney Pictures                              J.J. Abrams
# 4              Walt Disney Pictures                 Anthony Russo, Joe Russo
# 5                Universal Pictures                          Colin Trevorrow
# 6              Walt Disney Pictures                              Jon Favreau
# 7              Walt Disney Pictures           Joss Whedon, Robert Downey Jr.
# 8                Universal Pictures                                James Wan
# 9              Walt Disney Pictures                              Joss Whedon
# 10             Walt Disney Pictures                 Jennifer Lee, Chris Buck
# 11                   Marvel Studios                             Ryan Coogler
# 12            Warner Bros. Pictures                         David Yates (II)
# 13             Walt Disney Pictures                             Rian Johnson
# 14               Universal Pictures                              J.A. Bayona
# 15             Walt Disney Pictures                 Chris Buck, Jennifer Lee
# 16             Walt Disney Pictures                              Bill Condon
# 17                     Disney/Pixar                                Brad Bird
# 18               Universal Pictures                             F. Gary Gray
# 19             Walt Disney Pictures                              Shane Black
# 20               Universal Pictures                Pierre Coffin, Kyle Balda
# 21             Walt Disney Pictures                 Anthony Russo, Joe Russo
# 22            Warner Bros. Pictures                                James Wan
# 23                    Sony Pictures                                Jon Watts
# 24                   Marvel Studios                   Anna Boden, Ryan Fleck
# 25                Paramount Studios                              Michael Bay
# 26                  New Line Cinema                            Peter Jackson
# 27                              MGM                               Sam Mendes
# 28               Paramount Pictures                              Michael Bay
# 29            Warner Bros. Pictures                        Christopher Nolan
# 30                     Disney/Pixar                              Josh Cooley
# 31             Walt Disney Pictures                              Lee Unkrich
# 32                      Buena Vista                           Gore Verbinski
# 33            Warner Bros. Pictures                            Todd Phillips
# 34             Walt Disney Pictures                       Gareth Edwards (V)
# 35             Walt Disney Pictures                              Guy Ritchie
# 36             Walt Disney Pictures             Dariusz Wolski, Rob Marshall
# 37               Universal Pictures  Kyle Balda, Pierre Coffin, Eric Guillon
# 38           Universal City Studios                         Steven Spielberg
# 39       Walt Disney Pictures/PIXAR            Andrew Stanton, Angus MacLane
# 40                 20th Century Fox                             George Lucas
# 41             Walt Disney Pictures                               Tim Burton
# 42    Walt Disney Animation Studios     Byron Howard, Rich Moore, Jared Bush
# 43                     Warner Bros.                            Peter Jackson
# 44  Warner Bros. Pictures/Legendary                        Christopher Nolan
# 45             Walt Disney Pictures                              J.J. Abrams
# 46            Warner Bros. Pictures                           Chris Columbus
# 47               Universal Pictures              Pierre Coffin, Chris Renaud
# 48                      Buena Vista                Roger Allers, Rob Minkoff
# 49             Walt Disney Pictures                              Jon Favreau
