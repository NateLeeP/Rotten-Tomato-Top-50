# %%
import os
import pandas as pd
import matplotlib.pyplot as pltz
import re

# %%
os.chdir(r'C:\Users\Nate P\Desktop\Rotten Tomatoes Movies Analysis')

# %%
# Read in CSV
movies_df = pd.read_csv('movies_df.csv')
studios_df = pd.read_csv('studios_df_v2.csv')

# %%
# Below I am experimenting with different ways to merge the movies_df and studios_df DataFrames.
movies_df.join(studios_df[['Ratings','Studio','Director(s)']])
# Out:
#                                             Title  Box Office in $  \
# 0                               Avengers: Endgame       2798000000
# 1                                          Avatar       2790000000
# 2                                         Titanic       2188000000
# 3      Star Wars: Episode VII - The Force Awakens       2068000000
# 4                          Avengers: Infinity War       2048000000
# 5                                  Jurassic World       1672000000
# 6                                   The Lion King       1655000000
# 7                           Marvel's The Avengers       1519000000
# 8                                       Furious 7       1516000000
# 9                         Avengers: Age of Ultron       1405000000
# 10                                  Black Panther       1347000000
# 11  Harry Potter and the Deathly Hallows - Part 2       1342000000
# 12                       Star Wars: The Last Jedi       1333000000
# ...

# %%
# Merge not great for this, as names repeat in 'Title' column
movies_df.merge(right = studios_df, on = 'Title', how = 'left', indicator = True)
# Out:
#                                             Title  Box Office in $  \
# 0                               Avengers: Endgame       2798000000
# 1                                          Avatar       2790000000
# 2                                         Titanic       2188000000
# 3      Star Wars: Episode VII - The Force Awakens       2068000000
# 4                          Avengers: Infinity War       2048000000
# 5                                  Jurassic World       1672000000
# 6                                   The Lion King       1655000000
# 7                                   The Lion King       1655000000
# 8                           Marvel's The Avengers       1519000000
# 9                                       Furious 7       1516000000
# 10                        Avengers: Age of Ultron       1405000000
# 11                                      Frozen II       1371000000
# 12                                  Black Panther       1347000000
# ...

# %%
# Join works by matching a column to an index. Must change studios_df to having the movie titles as index. 
# With the movie titles as index, we can use the 'Title' column. TWO LION KING MOVIES!! How to fix? Need to fix in merging. 
studios_title_index_df = studios_df.set_index('Title')
movies_df.join(studios_title_index_df, on = 'Title')
# Out:
#                                             Title  Box Office in $  \
# 0                               Avengers: Endgame       2798000000
# 1                                          Avatar       2790000000
# 2                                         Titanic       2188000000
# 3      Star Wars: Episode VII - The Force Awakens       2068000000
# 4                          Avengers: Infinity War       2048000000
# 5                                  Jurassic World       1672000000
# 6                                   The Lion King       1655000000
# 6                                   The Lion King       1655000000
# 7                           Marvel's The Avengers       1519000000
# 8                                       Furious 7       1516000000
# 9                         Avengers: Age of Ultron       1405000000
# 10                                  Black Panther       1347000000
# 11  Harry Potter and the Deathly Hallows - Part 2       1342000000
# ...

# %%
#pd.concat and DataFrame.join() methods work. Join works because both share an index, but need to remove ['Title'] column.
pd.concat([movies_df,studios_df[['Ratings','Studio','Director(s)']]], axis = 1)
# Out:
#                                             Title  Box Office in $  \
# 0                               Avengers: Endgame       2798000000
# 1                                          Avatar       2790000000
# 2                                         Titanic       2188000000
# 3      Star Wars: Episode VII - The Force Awakens       2068000000
# 4                          Avengers: Infinity War       2048000000
# 5                                  Jurassic World       1672000000
# 6                                   The Lion King       1655000000
# 7                           Marvel's The Avengers       1519000000
# 8                                       Furious 7       1516000000
# 9                         Avengers: Age of Ultron       1405000000
# 10                                      Frozen II       1371000000
# 11                                  Black Panther       1347000000
# 12  Harry Potter and the Deathly Hallows - Part 2       1342000000
# ...

# %%
movie_studio_df = movies_df.join(studios_df[['Ratings','Studio','Director(s)']])

# %%
movie_studio_df
# Out:
#                                             Title  Box Office in $  \
# 0                               Avengers: Endgame       2798000000
# 1                                          Avatar       2790000000
# 2                                         Titanic       2188000000
# 3      Star Wars: Episode VII - The Force Awakens       2068000000
# 4                          Avengers: Infinity War       2048000000
# 5                                  Jurassic World       1672000000
# 6                                   The Lion King       1655000000
# 7                           Marvel's The Avengers       1519000000
# 8                                       Furious 7       1516000000
# 9                         Avengers: Age of Ultron       1405000000
# 10                                      Frozen II       1371000000
# 11                                  Black Panther       1347000000
# 12  Harry Potter and the Deathly Hallows - Part 2       1342000000
# ...

# %%
# Save movie_studio_df.csv. This is a csv with TItle, Box Office, Year, RAting, Studio, and Director
movie_studio_df.to_csv('movie_studio_df.csv', index = False)

# %%
pd.read_csv('movie_studio_df.csv')
# Out:
#                                             Title  Box Office in $  \
# 0                               Avengers: Endgame       2798000000
# 1                                          Avatar       2790000000
# 2                                         Titanic       2188000000
# 3      Star Wars: Episode VII - The Force Awakens       2068000000
# 4                          Avengers: Infinity War       2048000000
# 5                                  Jurassic World       1672000000
# 6                                   The Lion King       1655000000
# 7                           Marvel's The Avengers       1519000000
# 8                                       Furious 7       1516000000
# 9                         Avengers: Age of Ultron       1405000000
# 10                                      Frozen II       1371000000
# 11                                  Black Panther       1347000000
# 12  Harry Potter and the Deathly Hallows - Part 2       1342000000
# ...

# %%
S
